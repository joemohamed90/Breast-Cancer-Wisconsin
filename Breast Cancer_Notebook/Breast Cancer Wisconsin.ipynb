# %% [markdown]
# importing the required libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.metrics import mean_squared_error,r2_score,classification_report,accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load and Prepare the Data

# %%
df=pd.read_csv("Breast Cancer Wisconsin.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df['diagnosis'].replace({"M" : "1" , "B" : "0"},inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.drop('id',axis=1,inplace=True)
df.drop('Unnamed: 32',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# Data Visualizations

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='diagnosis', data=df)
plt.title('Distribution of Diagnosis')
plt.show()

# %% [markdown]
# Pairplot for Visualizing Relationships

# %%
# Pairplot with a broader selection of features
selected_features = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'diagnosis']
sns.pairplot(df[selected_features], hue='diagnosis', palette='Set1', diag_kind='kde')
plt.show()

# %%
# Boxplot for a few features against the 'diagnosis' column
selected_features = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean']
for feature in selected_features:
    plt.subplot(2,2, selected_features.index(feature) + 1)
    sns.boxplot(data=df, x='diagnosis', y=feature)
    plt.title(f'{feature} vs. diagnosis')
plt.tight_layout()
plt.show()

# %% [markdown]
# Histogram and KDE Plot

# %%
# Histogram and KDE plot for 'radius_mean'
plt.figure(figsize=(9, 8))
sns.histplot(df['radius_mean'], kde=True, bins=30, color='blue')
plt.title('Histogram and KDE of Radius Mean')
plt.show()

# Histogram and KDE plot for 'area_mean'
plt.figure(figsize=(9, 8))
sns.histplot(df['area_mean'], kde=True, bins=30, color='red')
plt.title('Histogram and KDE of Area Mean')
plt.show()

# %% [markdown]
#  Compute the correlation matrix

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr() , annot=True, cmap='mako')
plt.title('Correlation Heatmap of Features')
plt.show()

# %% [markdown]
# Splitting the dataset

# %%
X=df.drop(['diagnosis'],axis=1)
y=df['diagnosis']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)

# %% [markdown]
# Standardize the features

# %%
S=StandardScaler()
X_train=S.fit_transform(X_train)
X_test=S.transform(X_test)

# %% [markdown]
# Model training

# %%
logistic=LogisticRegression()
logistic.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Predictions

# %%
y_pred=logistic.predict(X_test)

# %% [markdown]
# Evaluate the model

# %%
mse = mean_squared_error(y_test, y_pred)
r2_square = r2_score(y_test,y_pred)
print(f" R-squared: {r2_square}")
print(f'Mean Squared Error: {mse}')
# Out:
#  R-squared: 0.9623015873015873
# Mean Squared Error: 0.008771929824561403

# %% [markdown]
# Visualization of Model Performance

# %%
print("Confusion Matrix")
ConfusionMatrixDisplay.from_estimator(logistic, X_test, y_test, cmap='Blues')
plt.show()
# Out:
# Confusion Matrix

# %%
print("Normalized Confusion Matrix")
ConfusionMatrixDisplay.from_estimator(logistic, X_test, y_test,normalize='true' ,cmap='Blues')
plt.show()
# Out:
# Normalized Confusion Matrix

# %%
print("confusion_matrix : \n",confusion_matrix(y_test,y_pred))
print('classification_report : \n',classification_report(y_test,y_pred))
print("accuracy_score : \n",accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
#  [[72  0]
#  [ 1 41]]
# classification_report :
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        72
#            1       1.00      0.98      0.99        42
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# accuracy_score :
#  0.9912280701754386
